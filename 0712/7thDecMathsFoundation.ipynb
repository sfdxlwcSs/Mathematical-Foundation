# %%
import numpy  as np

# %%
# Create a large 2D array (1000 x 1000)
large_2d_array = np.random.rand(1000, 1000)

# Basic Operations
print(f"Shape: {large_2d_array.shape}")       # Output: (1000, 1000)
print(f"Max Value: {large_2d_array.max()}")   # Maximum value in the array
print(f"Row-wise Sum: {large_2d_array.sum(axis=1)}")  # Sum of each row
# Out:
# Shape: (1000, 1000)
# Max Value: 0.9999985935555735
# Row-wise Sum: [513.25339189 497.94011908 496.56491771 495.86124944 498.74542146
#  500.73543265 505.82500146 497.72088749 506.36886234 497.22137147
#  502.60054041 511.19903814 504.93990385 498.44675531 500.1997995
#  499.27020134 494.35616946 507.18704315 502.35554193 503.57226619
#  487.15829317 502.66348567 489.01272375 495.3230159  498.04694121
#  515.78340117 492.36538548 500.54960689 496.26720595 500.40086636
#  495.60173512 515.63527889 489.84045545 503.14914682 486.64371805
#  491.48711913 509.65139777 512.42435207 499.29038516 507.19604054
#  491.52469118 486.9550771  504.61983706 505.69442569 504.03265837
#  499.29143076 495.01434582 503.11072186 512.42484825 492.76109701
#  499.46289597 506.32470116 509.02018277 501.49364181 505.77637147
#  503.70986663 522.48298166 508.17327277 500.79052117 506.42007709
#  507.43621076 509.32431505 496.01752074 485.2557539  488.15211896
# ...

# %%
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.array([7,8,9])
k=3
m=3
print("a+b=",a+b)
# Out:
# a+b= [5 7 9]

# %%
print("a+b=",b+a)
# Out:
# a+b= [5 7 9]

# %%
print("a+b== b+a:",np.array_equal((a+b),(b+a))) # commutaive property
# Out:
# a+b== b+a: True

# %%
# Associate property

# %%
zero_vector=np.zeros_like(a)
print('Additive identity')
print("a+0=",a+zero_vector)
# Out:
# Additive identity
# a+0= [1 2 3]

# %%
print("Multiplicative Identity")
print("1a=",1*a)
# Out:
# Multiplicative Identity
# 1a= [1 2 3]

# %%
def calculate_norms(vector):
    l1_norm=np.sum(np.abs(vector))
    l2_norm=np.sqrt(np.sum(vector**2))
    l2_norm=np.max(np.abs(vector))
    return l1_norm,l2_norm,l2_norm

# %%
def calculate_distance(vector1,vector2):
    diff_vector=vector-vector1-vector2
    li_distance=np.sum(np.abs(diff_vector))
    l2_distance=np.sqrt(np.sum(diff_vector**2))
    chebyshev_distance=np.max(np.abs(diff_vector))
